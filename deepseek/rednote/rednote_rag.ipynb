# %% [markdown]
# # DeepSeek Agent + RAG 实战：小红书爆款文案生成助手
#
# ## 1. 环境准备与DeepSeek API配置

# %%
# !pip install "pymilvus[model]==2.5.10" openai==1.82.0 requests==2.32.3 tqdm==4.67.1 torch==2.7.0
# Out:
# Requirement already satisfied: pymilvus==2.5.10 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pymilvus[model]==2.5.10) (2.5.10)
# Requirement already satisfied: openai==1.82.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (1.82.0)
# Requirement already satisfied: requests==2.32.3 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (2.32.3)
# Requirement already satisfied: tqdm==4.67.1 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (4.67.1)
# Requirement already satisfied: torch==2.7.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (2.7.0)
# Requirement already satisfied: setuptools>69 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pymilvus==2.5.10->pymilvus[model]==2.5.10) (80.9.0)
# Requirement already satisfied: grpcio<=1.67.1,>=1.49.1 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pymilvus==2.5.10->pymilvus[model]==2.5.10) (1.67.1)
# Requirement already satisfied: protobuf>=3.20.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pymilvus==2.5.10->pymilvus[model]==2.5.10) (6.33.4)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pymilvus==2.5.10->pymilvus[model]==2.5.10) (1.2.1)
# Requirement already satisfied: ujson>=2.0.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pymilvus==2.5.10->pymilvus[model]==2.5.10) (5.11.0)
# Requirement already satisfied: pandas>=1.2.4 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pymilvus==2.5.10->pymilvus[model]==2.5.10) (2.3.3)
# Requirement already satisfied: milvus-lite>=2.4.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pymilvus==2.5.10->pymilvus[model]==2.5.10) (2.5.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from openai==1.82.0) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from openai==1.82.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from openai==1.82.0) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from openai==1.82.0) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from openai==1.82.0) (2.12.5)
# Requirement already satisfied: sniffio in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from openai==1.82.0) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from openai==1.82.0) (4.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from requests==2.32.3) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from requests==2.32.3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from requests==2.32.3) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from requests==2.32.3) (2026.1.4)
# Requirement already satisfied: filelock in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from torch==2.7.0) (3.20.3)
# Requirement already satisfied: sympy>=1.13.3 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from torch==2.7.0) (1.14.0)
# Requirement already satisfied: networkx in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from torch==2.7.0) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from torch==2.7.0) (3.1.6)
# Requirement already satisfied: fsspec in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from torch==2.7.0) (2026.1.0)
# Requirement already satisfied: pymilvus.model>=0.3.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pymilvus[model]==2.5.10) (0.3.2)
# Requirement already satisfied: httpcore==1.* in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai==1.82.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.82.0) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai==1.82.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai==1.82.0) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai==1.82.0) (0.4.2)
# Requirement already satisfied: numpy>=1.26.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pandas>=1.2.4->pymilvus==2.5.10->pymilvus[model]==2.5.10) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pandas>=1.2.4->pymilvus==2.5.10->pymilvus[model]==2.5.10) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pandas>=1.2.4->pymilvus==2.5.10->pymilvus[model]==2.5.10) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pandas>=1.2.4->pymilvus==2.5.10->pymilvus[model]==2.5.10) (2025.3)
# Requirement already satisfied: transformers>=4.36.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pymilvus.model>=0.3.0->pymilvus[model]==2.5.10) (4.57.6)
# Requirement already satisfied: onnxruntime in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pymilvus.model>=0.3.0->pymilvus[model]==2.5.10) (1.23.2)
# Requirement already satisfied: scipy>=1.10.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from pymilvus.model>=0.3.0->pymilvus[model]==2.5.10) (1.17.0)
# Requirement already satisfied: six>=1.5 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus==2.5.10->pymilvus[model]==2.5.10) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from sympy>=1.13.3->torch==2.7.0) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]==2.5.10) (0.36.0)
# Requirement already satisfied: packaging>=20.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]==2.5.10) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]==2.5.10) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]==2.5.10) (2026.1.15)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]==2.5.10) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]==2.5.10) (0.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]==2.5.10) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from jinja2->torch==2.7.0) (3.0.3)
# Requirement already satisfied: coloredlogs in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from onnxruntime->pymilvus.model>=0.3.0->pymilvus[model]==2.5.10) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from onnxruntime->pymilvus.model>=0.3.0->pymilvus[model]==2.5.10) (25.12.19)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages (from coloredlogs->onnxruntime->pymilvus.model>=0.3.0->pymilvus[model]==2.5.10) (10.0)

# %%
import os
from openai import OpenAI

# 建议将 API Key 设置为环境变量，避免直接暴露在代码中
# 从环境变量获取 DeepSeek API Key
api_key = os.getenv("DEEPSEEK_API_KEY")
if not api_key:
    raise ValueError("请设置 DEEPSEEK_API_KEY 环境变量")

# 初始化 DeepSeek 客户端

client = OpenAI(
    api_key=api_key,
    base_url="https://api.deepseek.com/v1",  # DeepSeek API 的基地址
)

# %% [markdown]
# ## 2. RAG

# %% [markdown]
# ### 2.1 准备Embedding模型

# %%
from pymilvus import model as milvus_model

embedding_model = milvus_model.DefaultEmbeddingFunction()

# 生成测试向量，查看维度
test_embedding = embedding_model.encode_queries(["小红书的爆款文案咋写？"])[0]
embedding_dim = len(test_embedding)
print(embedding_dim)
# Out:
# '(ProtocolError('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer')), '(Request ID: 07d0cea4-56e0-4f3b-9608-266e38782bdf)')' thrown while requesting HEAD https://huggingface.co/GPTCache/paraphrase-albert-small-v2/resolve/main/tokenizer_config.json
# Retrying in 1s [Retry 1/5].
# '(ProtocolError('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer')), '(Request ID: bec27c37-8ffc-4906-a3b7-6ba562afced8)')' thrown while requesting HEAD https://huggingface.co/GPTCache/paraphrase-albert-small-v2/resolve/main/tokenizer_config.json
# Retrying in 2s [Retry 2/5].
# '(ProtocolError('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer')), '(Request ID: b326ba74-f72c-48ea-ad33-d628bce02fbe)')' thrown while requesting HEAD https://huggingface.co/GPTCache/paraphrase-albert-small-v2/resolve/main/tokenizer_config.json
# Retrying in 4s [Retry 3/5].
# '(ProtocolError('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer')), '(Request ID: cce2fac2-64f4-43a9-b00b-458be705121c)')' thrown while requesting HEAD https://huggingface.co/GPTCache/paraphrase-albert-small-v2/resolve/main/tokenizer_config.json
# Retrying in 8s [Retry 4/5].
# 768

# %% [markdown]
# ### 2.2 创建collection

# %%
from pymilvus import MilvusClient

milvus_client = MilvusClient(uri="./rednote_rga.db")

collection_name = "rednote_rag"

if milvus_client.has_collection(collection_name):
    milvus_client.drop_collection(collection_name)

milvus_client.create_collection(
    collection_name=collection_name,
    dimension=embedding_dim,
    metric_type="IP",
    consistency_level="Strong",
)
# Out:
# /Users/hank/miniconda3/envs/deepseek/lib/python3.13/site-packages/milvus_lite/__init__.py:15: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %% [markdown]
# ### 2.3 获取基础数据

# %%
import re

with open('product_info.md', 'r', encoding='utf-8') as file:
    content = file.read()

text_lines =  [content]

# %% [markdown]
# ### 2.4 写入数据到向量数据库

# %%
from tqdm import tqdm

data = []

doc_embeddings = embedding_model.encode_documents(text_lines)

for i, line in enumerate(tqdm(text_lines, desc="创建向量")):
    data.append({"id": i+1, "vector": doc_embeddings[i], "text": line})

print(f"准备插入 {len(data)} 条数据到Milvus")

milvus_client.insert(collection_name=collection_name, data=data)
# Out:
# 创建向量: 100%|██████████| 1/1 [00:00<00:00, 24385.49it/s]
# 准备插入 1 条数据到Milvus
# {'insert_count': 1, 'ids': [1], 'cost': 0}

# %% [markdown]
# ### 2.5 定义RAG查询函数

# %%
def query_rag(question):
    search_res = milvus_client.search(
        collection_name=collection_name,
        data=embedding_model.encode_queries(
            [question]
        ),
        limit=5,
        search_params={"metric_type": "IP", "params": {}},  # 内积距离
        output_fields=["text"],  # 返回 text 字段
    )
    retrieved_lines_with_distances = [
        res["entity"]["text"] for res in search_res[0]
    ]

    return "\n".join(
        [line_with_text for line_with_text in retrieved_lines_with_distances]
    )

# %% [markdown]
# ### 2.5 定义RAG查询函数

# %% [markdown]
# ## 3. 爆款文案生成逻辑与 Prompt 设计
#
# ### 3.1 System Prompt (系统提示词)
#
# System Prompt 是 Agent 的“大脑”和“行为准则”。它定义了 Agent 的角色、目标以及工作方式。我们将采用 `Thought-Action-Observation` (ReAct) 模式来引导 DeepSeek 的推理过程。

# %%
SYSTEM_PROMPT = """
你是一个资深的小红书爆款文案专家，擅长结合最新潮流和产品卖点，创作引人入胜、高互动、高转化的笔记文案。

你的任务是根据用户提供的产品和需求，生成包含标题、正文、相关标签和表情符号的完整小红书笔记。

请始终采用'Thought-Action-Observation'模式进行推理和行动。文案风格需活泼、真诚、富有感染力。当完成任务后，请以JSON格式直接输出最终文案，格式如下：
```json
{
  "title": "小红书标题",
  "body": "小红书正文",
  "hashtags": ["#标签1", "#标签2", "#标签3", "#标签4", "#标签5"],
  "emojis": ["✨", "🔥", "💖"]
}
```
在生成文案前，请务必先思考并收集足够的信息。
"""

# %% [markdown]
# ### 3.2 Tools (工具定义)
#
# Agent 的“双手”由一系列可调用的工具组成。这些工具扩展了 LLM 的能力，使其能够获取实时信息、查询数据库或执行特定操作。在这里，我们定义了三个核心工具：
#
# *   `search_web`: 用于搜索互联网上的实时信息，如最新趋势、用户评价等。
# *   `query_product_database`: 用于查询产品数据库，获取产品的详细卖点和特点。**此工具为模拟**。
# *   `generate_emoji`: 用于根据文案内容生成恰当的表情符号。**此工具为模拟**。

# %%
TOOLS_DEFINITION = [
    {
        "type": "function",
        "function": {
            "name": "search_web",
            "description": "搜索互联网上的实时信息，用于获取最新新闻、流行趋势、用户评价、行业报告等。请确保搜索关键词精确，避免宽泛的查询。",
            "parameters": {
                "type": "object",
                "properties": {
                    "query": {
                        "type": "string",
                        "description": "要搜索的关键词或问题，例如'最新小红书美妆趋势'或'深海蓝藻保湿面膜 用户评价'"
                    }
                },
                "required": ["query"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "query_product_database",
            "description": "查询内部产品数据库，获取指定产品的详细卖点、成分、适用人群、使用方法等信息。",
            "parameters": {
                "type": "object",
                "properties": {
                    "product_name": {
                        "type": "string",
                        "description": "要查询的产品名称，例如'深海蓝藻保湿面膜'"
                    }
                },
                "required": ["product_name"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "generate_emoji",
            "description": "根据提供的文本内容，生成一组适合小红书风格的表情符号。",
            "parameters": {
                "type": "object",
                "properties": {
                    "context": {
                        "type": "string",
                        "description": "文案的关键内容或情感，例如'惊喜效果'、'补水保湿'"
                    }
                },
                "required": ["context"]
            }
        }
    }
]

# %% [markdown]
# ### 3.3 模拟工具实现
#
# 由于我们无法直接调用真实的外部 API (如Google Search或内部产品数据库)，我们将创建一些模拟 (Mock) 工具函数来演示 Agent 的工作流程。在实际应用中，您需要将这些模拟函数替换为真实的 API 调用。

# %%
import random # 用于模拟生成表情
import time # 用于模拟网络延迟

def mock_search_web(query: str) -> str:
    """模拟网页搜索工具，返回预设的搜索结果。"""
    print(f"[Tool Call] 模拟搜索网页：{query}")
    time.sleep(1) # 模拟网络延迟
    if "小红书美妆趋势" in query:
        return "近期小红书美妆流行'多巴胺穿搭'、'早C晚A'护肤理念、'伪素颜'妆容，热门关键词有#氛围感、#抗老、#屏障修复。"
    elif "保湿面膜" in query:
        return "小红书保湿面膜热门话题：沙漠干皮救星、熬夜急救面膜、水光肌养成。用户痛点：卡粉、泛红、紧绷感。"
    elif "深海蓝藻保湿面膜" in query:
        return "关于深海蓝藻保湿面膜的用户评价：普遍反馈补水效果好，吸收快，对敏感肌友好。有用户提到价格略高，但效果值得。"
    elif "祛痘" in query:
        return "祛痘热门话题：刷酸祛痘、茶树精油、维A酸。用户痛点：痘痘、痘印、痘坑。"
    elif "祛痘贴" in query:
        return "小红书讨论的祛痘贴优缺点：隐形无感、覆盖快速消炎，入门款推荐TeaTree Care、星星祛痘贴。网友提醒需选合适的成分以免敏感。"
    else:
        return f"未找到关于 '{query}' 的特定信息，但市场反馈通常关注产品成分、功效和用户体验。"

def query_product_database(product_name: str) -> str:
    """模拟查询产品数据库，返回预设的产品信息。"""
    print(f"[Tool Call] 查询产品数据库：{product_name}")
    content = query_rag(product_name)
    print(f"查询到产品信息：{content}")
    return content

def mock_generate_emoji(context: str) -> list:
    """模拟生成表情符号，根据上下文提供常用表情。"""
    print(f"[Tool Call] 模拟生成表情符号，上下文：{context}")
    time.sleep(0.2) # 模拟生成延迟
    if "补水" in context or "水润" in context or "保湿" in context:
        return ["💦", "💧", "🌊", "✨"]
    elif "惊喜" in context or "哇塞" in context or "爱了" in context:
        return ["💖", "😍", "🤩", "💯"]
    elif "熬夜" in context or "疲惫" in context:
        return ["😭", "😮‍💨", "😴", "💡"]
    elif "好物" in context or "推荐" in context:
        return ["✅", "👍", "⭐", "🛍️"]
    elif "祛痘" in context or "痘印" in context or "痘坑" in context:
        return ["🧑‍⚕️", "🩹", "😀", "💊"]
    else:
        return random.sample(["✨", "🔥", "💖", "💯", "🎉", "👍", "🤩", "💧", "🌿"], k=min(5, len(context.split())))

# 将模拟工具函数映射到一个字典，方便通过名称调用
available_tools = {
    "search_web": mock_search_web,
    "query_product_database": query_product_database,
    "generate_emoji": mock_generate_emoji,
}

# %% [markdown]
# ## 4. 实战：构建小红书文案生成 Agent
#
# 现在，我们将把 System Prompt、工具定义和模拟工具函数整合起来，构建出能够自动执行的 DeepSeek Agent 工作流。核心是 `generate_rednote` 函数，它通过一个循环来模拟 Agent 的 `Thought-Action-Observation` 过程。

# %%
import json
import re

def generate_rednote(product_name: str, tone_style: str = "活泼甜美", max_iterations: int = 7) -> str:
    """
    使用 DeepSeek Agent 生成小红书爆款文案。
    
    Args:
        product_name (str): 要生成文案的产品名称。
        tone_style (str): 文案的语气和风格，如"活泼甜美"、"知性"、"搞怪"等。
        max_iterations (int): Agent 最大迭代次数，防止无限循环。
        
    Returns:
        str: 生成的爆款文案（JSON 格式字符串）。
    """
    
    print(f"\n🚀 启动小红书文案生成助手，产品：{product_name}，风格：{tone_style}\n")
    
    # 存储对话历史，包括系统提示词和用户请求
    messages = [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": f"请为产品「{product_name}」生成一篇小红书爆款文案。要求：语气{tone_style}，包含标题、正文、至少5个相关标签和5个表情符号。请以完整的JSON格式输出，并确保JSON内容用markdown代码块包裹（例如：```json{{...}}```）。"}
    ]
    
    iteration_count = 0
    final_response = None
    
    while iteration_count < max_iterations:
        iteration_count += 1
        print(f"-- Iteration {iteration_count} --")
        
        try:
            # 调用 DeepSeek API，传入对话历史和工具定义
            response = client.chat.completions.create(
                model="deepseek-chat",
                messages=messages,
                tools=TOOLS_DEFINITION, # 告知模型可用的工具
                tool_choice="auto" # 允许模型自动决定是否使用工具
            )

            response_message = response.choices[0].message
            
            # **ReAct模式：处理工具调用**
            if response_message.tool_calls: # 如果模型决定调用工具
                print("Agent: 决定调用工具...")
                messages.append(response_message) # 将工具调用信息添加到对话历史
                
                tool_outputs = []
                for tool_call in response_message.tool_calls:
                    function_name = tool_call.function.name
                    # 确保参数是合法的JSON字符串，即使工具不要求参数，也需要传递空字典
                    function_args = json.loads(tool_call.function.arguments) if tool_call.function.arguments else {}

                    print(f"Agent Action: 调用工具 '{function_name}'，参数：{function_args}")
                    
                    # 查找并执行对应的模拟工具函数
                    if function_name in available_tools:
                        tool_function = available_tools[function_name]
                        tool_result = tool_function(**function_args)
                        print(f"Observation: 工具返回结果：{tool_result}")
                        tool_outputs.append({
                            "tool_call_id": tool_call.id,
                            "role": "tool",
                            "content": str(tool_result) # 工具结果作为字符串返回
                        })
                    else:
                        error_message = f"错误：未知的工具 '{function_name}'"
                        print(error_message)
                        tool_outputs.append({
                            "tool_call_id": tool_call.id,
                            "role": "tool",
                            "content": error_message
                        })
                messages.extend(tool_outputs) # 将工具执行结果作为 Observation 添加到对话历史
                
            # **ReAct 模式：处理最终内容**
            elif response_message.content: # 如果模型直接返回内容（通常是最终答案）
                print(f"[模型生成结果] {response_message.content}")
                
                # --- START: 添加 JSON 提取和解析逻辑 ---
                json_string_match = re.search(r"```json\s*(\{.*\})\s*```", response_message.content, re.DOTALL)
                
                if json_string_match:
                    extracted_json_content = json_string_match.group(1)
                    try:
                        final_response = json.loads(extracted_json_content)
                        print("Agent: 任务完成，成功解析最终JSON文案。")
                        return json.dumps(final_response, ensure_ascii=False, indent=2)
                    except json.JSONDecodeError as e:
                        print(f"Agent: 提取到JSON块但解析失败: {e}")
                        print(f"尝试解析的字符串:\n{extracted_json_content}")
                        messages.append(response_message) # 解析失败，继续对话
                else:
                    # 如果没有匹配到 ```json 块，尝试直接解析整个 content
                    try:
                        final_response = json.loads(response_message.content)
                        print("Agent: 任务完成，直接解析最终JSON文案。")
                        return json.dumps(final_response, ensure_ascii=False, indent=2)
                    except json.JSONDecodeError:
                        print("Agent: 生成了非JSON格式内容或非Markdown JSON块，可能还在思考或出错。")
                        messages.append(response_message) # 非JSON格式，继续对话
                # --- END: 添加 JSON 提取和解析逻辑 ---
            else:
                print("Agent: 未知响应，可能需要更多交互。")
                break
                
        except Exception as e:
            print(f"调用 DeepSeek API 时发生错误: {e}")
            break
    
    print("\n⚠️ Agent 达到最大迭代次数或未能生成最终文案。请检查Prompt或增加迭代次数。")
    return "未能成功生成文案。"

# %% [markdown]
# ## 5. 实际测试与文案生成
#
# 现在，让我们调用我们构建的 `generate_rednote` 函数，看看它能生成什么样的爆款文案！

# %%
# 测试案例 1: 深海蓝藻保湿面膜
product_name_1 = "深海蓝藻保湿面膜"
tone_style_1 = "活泼甜美"
result_1 = generate_rednote(product_name_1, tone_style_1)

print("\n--- 生成的文案 1 ---")
print(result_1)
# Out:
# 🚀 启动小红书文案生成助手，产品：深海蓝藻保湿面膜，风格：活泼甜美
#
# -- Iteration 1 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'query_product_database'，参数：{'product_name': '深海蓝藻保湿面膜'}
# [Tool Call] 查询产品数据库：深海蓝藻保湿面膜
# 查询到产品信息：# 产品信息文档
#
# ## 一、深海蓝藻保湿面膜
#
# ### 1. 产品概述
# 深海蓝藻保湿面膜是一款采用深海蓝藻提取物为主要成分的深层保湿护肤产品，专为干燥、缺水肌肤设计。
#
# ### 2. 核心成分
# - **深海蓝藻提取物**：富含多种氨基酸、维生素和矿物质，具有强大的保湿锁水能力
# - **透明质酸钠**：小分子透明质酸，能够深入肌肤底层，提供持久保湿
# - **海藻糖**：天然保湿因子，帮助肌肤维持水分平衡
# - **维生素E**：抗氧化成分，保护肌肤免受自由基伤害
# - **甘油**：经典保湿成分，增强肌肤保水能力
#
# ### 3. 产品功效
# - 深层补水，快速缓解肌肤干燥问题
# - 增强肌肤锁水能力，维持24小时水润状态
# - 改善肌肤粗糙、暗沉现象
# - 舒缓敏感肌肤，减少泛红不适
# - 提升肌肤弹性，减少细纹产生
# - 平衡肌肤水油状态，适合各种肤质
#
# ### 4. 适用人群
# - 干性肌肤、混合性偏干肌肤
# - 因环境因素导致肌肤缺水的用户
# - 经常熬夜、作息不规律的人群
# - 需要快速补水急救的肌肤
# - 敏感肌（需先做过敏测试）
#
# ### 5. 使用方法
# - 清洁面部后，取出面膜展开
# - 将面膜贴合面部，调整至最佳位置
# - 静敷15-20分钟，让精华充分吸收
# - 取下面膜后，轻轻按摩剩余精华至完全吸收
# - 建议每周使用2-3次，可根据肌肤状况调整频率
#
# ### 6. 产品规格
# - 单片装：25ml精华液
# - 盒装：10片/盒
# - 保质期：36个月
# - 储存条件：常温避光保存
#
# ### 7. 注意事项
# - 使用前请先做皮肤过敏测试
# - 如有伤口、炎症或过敏现象，请暂停使用
# - 使用后如出现不适，请立即停止使用并咨询医生
# - 请勿将产品放置在高温或阳光直射处
#
# ### 8. 产品特点
# - 采用天丝膜布，轻薄透气，贴合度极佳
# - 精华液质地清爽，不粘腻，易吸收
# - 无添加酒精、香精、色素等刺激性成分
# - 通过皮肤科医生测试，温和安全
#
# ---
#
# ## 二、美白精华
#
# ### 1. 产品概述
# 美白精华是一款高效美白护肤产品，采用多重美白成分复配，能够有效抑制黑色素生成，淡化已有色斑，提亮整体肤色。
#
# ### 2. 核心成分
# - **烟酰胺**：浓度5%，有效抑制黑色素向表皮转移，减少色斑形成
# - **维生素C衍生物**：稳定型VC，抗氧化同时提亮肤色
# - **熊果苷**：天然美白成分，抑制酪氨酸酶活性
# - **传明酸**：有效阻断黑色素生成通路
# - **透明质酸**：保湿同时促进美白成分吸收
# - **甘草提取物**：舒缓肌肤，减少炎症后色素沉着
#
# ### 3. 产品功效
# - 有效抑制黑色素生成，预防色斑形成
# - 淡化已有色斑、痘印、暗沉
# - 均匀肤色，提亮整体肌肤亮度
# - 改善肌肤暗黄、粗糙问题
# - 抗氧化，延缓肌肤老化
# - 收缩毛孔，改善肌肤细腻度
# - 减少炎症后色素沉着
#
# ### 4. 适用人群
# - 有美白需求的各类肌肤
# - 有色斑、痘印困扰的用户
# - 肌肤暗沉、肤色不均的人群
# - 希望提亮肤色的用户
# - 混合性、油性肌肤（干性肌肤需配合保湿产品）
#
# ### 5. 使用方法
# - 洁面后，使用爽肤水进行基础护理
# - 取2-3滴精华液于掌心，轻轻搓热
# - 均匀涂抹于面部，重点部位可加强使用
# - 用指腹轻轻按摩至完全吸收
# - 建议早晚使用，白天使用需配合防晒产品
# - 使用顺序：洁面→爽肤水→美白精华→乳液/面霜→防晒（白天）
#
# ### 6. 产品规格
# - 容量：30ml
# - 包装：滴管式设计，方便取用
# - 保质期：24个月
# - 开封后建议6个月内使用完毕
#
# ### 7. 注意事项
# - 首次使用建议在耳后或手臂内侧做过敏测试
# - 使用初期可能出现轻微刺激，属正常现象，可减少用量
# - 白天使用必须配合防晒产品，避免紫外线伤害
# - 敏感肌建议先建立耐受，从低频率开始使用
# - 避免与含酸类产品同时使用，以免过度刺激
#
# ### 8. 产品特点
# - 质地轻薄，易吸收，不搓泥
# - 温和配方，适合长期使用
# - 无添加香精、酒精等刺激性成分
# - 通过临床测试，有效改善肤色
#
# ### 9. 使用周期
# - 连续使用4周可见初步效果
# - 8-12周可看到明显改善
# - 建议坚持使用3-6个月获得最佳效果
#
# ---
#
# ## 三、祛痘贴
#
# ### 1. 产品概述
# 祛痘贴是一款针对痘痘问题的急救护理产品，采用水胶体技术，能够快速吸收痘痘分泌物，加速痘痘愈合，同时防止细菌感染。
#
# ### 2. 核心成分
# - **水胶体**：主要成分，快速吸收痘痘分泌物
# - **水杨酸**：浓度2%，温和去角质，疏通毛孔
# - **茶树精油**：天然抗菌成分，抑制痘痘细菌
# - **金缕梅提取物**：收敛毛孔，舒缓炎症
# - **透明质酸**：保持贴片湿润，促进愈合
#
# ### 3. 产品功效
# - 快速吸收痘痘分泌物，加速痘痘成熟
# - 隔离外界细菌，防止二次感染
# - 减少痘痘红肿、疼痛感
# - 加速痘痘愈合，缩短恢复时间
# - 防止手部接触，避免留下痘印
# - 淡化已有痘印，改善肌肤状态
#
# ### 4. 适用人群
# - 有痘痘困扰的各类肌肤
# - 偶尔长痘需要快速处理的人群
# - 容易留下痘印的肌肤
# - 需要隔离痘痘避免感染的用户
# - 希望快速恢复的痘痘肌
#
# ### 5. 使用方法
# - 清洁面部，确保痘痘区域干净
# - 对于已破的痘痘，轻轻挤出分泌物（注意卫生）
# - 撕下祛痘贴，将中心对准痘痘位置
# - 轻轻按压边缘，确保贴片完全贴合
# - 建议夜间使用，贴敷6-8小时
# - 第二天早上取下，可见贴片变白，说明已吸收分泌物
# - 连续使用至痘痘完全愈合
#
# ### 6. 产品规格
# - 规格：24片/盒（含不同尺寸）
# - 尺寸：大号（12mm）、中号（10mm）、小号（8mm）
# - 保质期：36个月
# - 包装：独立密封包装，保持卫生
#
# ### 7. 注意事项
# - 仅适用于已形成的痘痘，不适用于闭口粉刺
# - 使用前确保手部和面部清洁
# - 如有伤口或严重炎症，请咨询医生
# - 敏感肌使用前建议先做测试
# - 使用后如出现过敏反应，请立即停止使用
#
# ### 8. 产品特点
# - 超薄设计，贴合度高，不易脱落
# - 透明或肤色，白天使用也不明显
# - 防水设计，洗脸时不易脱落
# - 温和配方，适合敏感肌使用
#
# ### 9. 使用场景
# - 夜间护理：睡前使用，第二天早上取下
# - 日间急救：重要场合前快速处理痘痘
# - 运动后：防止汗水刺激痘痘
# - 化妆前：隔离痘痘，防止化妆品刺激
#
# ### 10. 配合使用建议
# - 配合温和洁面产品，保持肌肤清洁
# - 使用后可用舒缓精华或修复产品
# - 避免使用过于刺激的护肤品
# - 注意饮食和作息，从根源改善痘痘问题
#
# ---
#
# ## 产品组合使用建议
#
# ### 日常护肤流程
# 1. **早晨**：洁面 → 爽肤水 → 美白精华 → 乳液 → 防晒
# 2. **晚间**：洁面 → 爽肤水 → 美白精华 → 乳液/面霜
# 3. **每周2-3次**：使用深海蓝藻保湿面膜进行深层补水
# 4. **痘痘出现时**：使用祛痘贴进行急救处理
#
# ### 产品搭配优势
# - 美白精华 + 保湿面膜：美白同时保持肌肤水润，避免干燥
# - 祛痘贴 + 美白精华：快速处理痘痘，同时淡化痘印
# - 三款产品配合使用，可构建完整的护肤体系
#
# ### 购买建议
# - 首次使用建议先购买小规格产品进行试用
# - 根据肌肤状况和需求选择合适的产品组合
# - 注意查看产品成分，避免与已有护肤品成分冲突
#
# ---
#
# ## 总结
#
# 以上三款产品均为高品质护肤产品，针对不同肌肤问题提供专业解决方案。建议根据个人肌肤状况和需求，合理选择和使用，并坚持使用以获得最佳效果。如有任何疑问或不适，请及时咨询专业皮肤科医生。
#
# Observation: 工具返回结果：# 产品信息文档
#
# ## 一、深海蓝藻保湿面膜
#
# ### 1. 产品概述
# 深海蓝藻保湿面膜是一款采用深海蓝藻提取物为主要成分的深层保湿护肤产品，专为干燥、缺水肌肤设计。
#
# ### 2. 核心成分
# - **深海蓝藻提取物**：富含多种氨基酸、维生素和矿物质，具有强大的保湿锁水能力
# - **透明质酸钠**：小分子透明质酸，能够深入肌肤底层，提供持久保湿
# - **海藻糖**：天然保湿因子，帮助肌肤维持水分平衡
# - **维生素E**：抗氧化成分，保护肌肤免受自由基伤害
# - **甘油**：经典保湿成分，增强肌肤保水能力
#
# ### 3. 产品功效
# - 深层补水，快速缓解肌肤干燥问题
# - 增强肌肤锁水能力，维持24小时水润状态
# - 改善肌肤粗糙、暗沉现象
# - 舒缓敏感肌肤，减少泛红不适
# - 提升肌肤弹性，减少细纹产生
# - 平衡肌肤水油状态，适合各种肤质
#
# ### 4. 适用人群
# - 干性肌肤、混合性偏干肌肤
# - 因环境因素导致肌肤缺水的用户
# - 经常熬夜、作息不规律的人群
# - 需要快速补水急救的肌肤
# - 敏感肌（需先做过敏测试）
#
# ### 5. 使用方法
# - 清洁面部后，取出面膜展开
# - 将面膜贴合面部，调整至最佳位置
# - 静敷15-20分钟，让精华充分吸收
# - 取下面膜后，轻轻按摩剩余精华至完全吸收
# - 建议每周使用2-3次，可根据肌肤状况调整频率
#
# ### 6. 产品规格
# - 单片装：25ml精华液
# - 盒装：10片/盒
# - 保质期：36个月
# - 储存条件：常温避光保存
#
# ### 7. 注意事项
# - 使用前请先做皮肤过敏测试
# - 如有伤口、炎症或过敏现象，请暂停使用
# - 使用后如出现不适，请立即停止使用并咨询医生
# - 请勿将产品放置在高温或阳光直射处
#
# ### 8. 产品特点
# - 采用天丝膜布，轻薄透气，贴合度极佳
# - 精华液质地清爽，不粘腻，易吸收
# - 无添加酒精、香精、色素等刺激性成分
# - 通过皮肤科医生测试，温和安全
#
# ---
#
# ## 二、美白精华
#
# ### 1. 产品概述
# 美白精华是一款高效美白护肤产品，采用多重美白成分复配，能够有效抑制黑色素生成，淡化已有色斑，提亮整体肤色。
#
# ### 2. 核心成分
# - **烟酰胺**：浓度5%，有效抑制黑色素向表皮转移，减少色斑形成
# - **维生素C衍生物**：稳定型VC，抗氧化同时提亮肤色
# - **熊果苷**：天然美白成分，抑制酪氨酸酶活性
# - **传明酸**：有效阻断黑色素生成通路
# - **透明质酸**：保湿同时促进美白成分吸收
# - **甘草提取物**：舒缓肌肤，减少炎症后色素沉着
#
# ### 3. 产品功效
# - 有效抑制黑色素生成，预防色斑形成
# - 淡化已有色斑、痘印、暗沉
# - 均匀肤色，提亮整体肌肤亮度
# - 改善肌肤暗黄、粗糙问题
# - 抗氧化，延缓肌肤老化
# - 收缩毛孔，改善肌肤细腻度
# - 减少炎症后色素沉着
#
# ### 4. 适用人群
# - 有美白需求的各类肌肤
# - 有色斑、痘印困扰的用户
# - 肌肤暗沉、肤色不均的人群
# - 希望提亮肤色的用户
# - 混合性、油性肌肤（干性肌肤需配合保湿产品）
#
# ### 5. 使用方法
# - 洁面后，使用爽肤水进行基础护理
# - 取2-3滴精华液于掌心，轻轻搓热
# - 均匀涂抹于面部，重点部位可加强使用
# - 用指腹轻轻按摩至完全吸收
# - 建议早晚使用，白天使用需配合防晒产品
# - 使用顺序：洁面→爽肤水→美白精华→乳液/面霜→防晒（白天）
#
# ### 6. 产品规格
# - 容量：30ml
# - 包装：滴管式设计，方便取用
# - 保质期：24个月
# - 开封后建议6个月内使用完毕
#
# ### 7. 注意事项
# - 首次使用建议在耳后或手臂内侧做过敏测试
# - 使用初期可能出现轻微刺激，属正常现象，可减少用量
# - 白天使用必须配合防晒产品，避免紫外线伤害
# - 敏感肌建议先建立耐受，从低频率开始使用
# - 避免与含酸类产品同时使用，以免过度刺激
#
# ### 8. 产品特点
# - 质地轻薄，易吸收，不搓泥
# - 温和配方，适合长期使用
# - 无添加香精、酒精等刺激性成分
# - 通过临床测试，有效改善肤色
#
# ### 9. 使用周期
# - 连续使用4周可见初步效果
# - 8-12周可看到明显改善
# - 建议坚持使用3-6个月获得最佳效果
#
# ---
#
# ## 三、祛痘贴
#
# ### 1. 产品概述
# 祛痘贴是一款针对痘痘问题的急救护理产品，采用水胶体技术，能够快速吸收痘痘分泌物，加速痘痘愈合，同时防止细菌感染。
#
# ### 2. 核心成分
# - **水胶体**：主要成分，快速吸收痘痘分泌物
# - **水杨酸**：浓度2%，温和去角质，疏通毛孔
# - **茶树精油**：天然抗菌成分，抑制痘痘细菌
# - **金缕梅提取物**：收敛毛孔，舒缓炎症
# - **透明质酸**：保持贴片湿润，促进愈合
#
# ### 3. 产品功效
# - 快速吸收痘痘分泌物，加速痘痘成熟
# - 隔离外界细菌，防止二次感染
# - 减少痘痘红肿、疼痛感
# - 加速痘痘愈合，缩短恢复时间
# - 防止手部接触，避免留下痘印
# - 淡化已有痘印，改善肌肤状态
#
# ### 4. 适用人群
# - 有痘痘困扰的各类肌肤
# - 偶尔长痘需要快速处理的人群
# - 容易留下痘印的肌肤
# - 需要隔离痘痘避免感染的用户
# - 希望快速恢复的痘痘肌
#
# ### 5. 使用方法
# - 清洁面部，确保痘痘区域干净
# - 对于已破的痘痘，轻轻挤出分泌物（注意卫生）
# - 撕下祛痘贴，将中心对准痘痘位置
# - 轻轻按压边缘，确保贴片完全贴合
# - 建议夜间使用，贴敷6-8小时
# - 第二天早上取下，可见贴片变白，说明已吸收分泌物
# - 连续使用至痘痘完全愈合
#
# ### 6. 产品规格
# - 规格：24片/盒（含不同尺寸）
# - 尺寸：大号（12mm）、中号（10mm）、小号（8mm）
# - 保质期：36个月
# - 包装：独立密封包装，保持卫生
#
# ### 7. 注意事项
# - 仅适用于已形成的痘痘，不适用于闭口粉刺
# - 使用前确保手部和面部清洁
# - 如有伤口或严重炎症，请咨询医生
# - 敏感肌使用前建议先做测试
# - 使用后如出现过敏反应，请立即停止使用
#
# ### 8. 产品特点
# - 超薄设计，贴合度高，不易脱落
# - 透明或肤色，白天使用也不明显
# - 防水设计，洗脸时不易脱落
# - 温和配方，适合敏感肌使用
#
# ### 9. 使用场景
# - 夜间护理：睡前使用，第二天早上取下
# - 日间急救：重要场合前快速处理痘痘
# - 运动后：防止汗水刺激痘痘
# - 化妆前：隔离痘痘，防止化妆品刺激
#
# ### 10. 配合使用建议
# - 配合温和洁面产品，保持肌肤清洁
# - 使用后可用舒缓精华或修复产品
# - 避免使用过于刺激的护肤品
# - 注意饮食和作息，从根源改善痘痘问题
#
# ---
#
# ## 产品组合使用建议
#
# ### 日常护肤流程
# 1. **早晨**：洁面 → 爽肤水 → 美白精华 → 乳液 → 防晒
# 2. **晚间**：洁面 → 爽肤水 → 美白精华 → 乳液/面霜
# 3. **每周2-3次**：使用深海蓝藻保湿面膜进行深层补水
# 4. **痘痘出现时**：使用祛痘贴进行急救处理
#
# ### 产品搭配优势
# - 美白精华 + 保湿面膜：美白同时保持肌肤水润，避免干燥
# - 祛痘贴 + 美白精华：快速处理痘痘，同时淡化痘印
# - 三款产品配合使用，可构建完整的护肤体系
#
# ### 购买建议
# - 首次使用建议先购买小规格产品进行试用
# - 根据肌肤状况和需求选择合适的产品组合
# - 注意查看产品成分，避免与已有护肤品成分冲突
#
# ---
#
# ## 总结
#
# 以上三款产品均为高品质护肤产品，针对不同肌肤问题提供专业解决方案。建议根据个人肌肤状况和需求，合理选择和使用，并坚持使用以获得最佳效果。如有任何疑问或不适，请及时咨询专业皮肤科医生。
#
# -- Iteration 2 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'search_web'，参数：{'query': '2024年面膜流行趋势 小红书爆款面膜 保湿面膜用户评价'}
# [Tool Call] 模拟搜索网页：2024年面膜流行趋势 小红书爆款面膜 保湿面膜用户评价
# Observation: 工具返回结果：小红书保湿面膜热门话题：沙漠干皮救星、熬夜急救面膜、水光肌养成。用户痛点：卡粉、泛红、紧绷感。
# -- Iteration 3 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'generate_emoji'，参数：{'context': '深海蓝藻保湿面膜 补水保湿 水光肌 惊喜效果'}
# [Tool Call] 模拟生成表情符号，上下文：深海蓝藻保湿面膜 补水保湿 水光肌 惊喜效果
# Observation: 工具返回结果：['💦', '💧', '🌊', '✨']
# -- Iteration 4 --
# [模型生成结果] **Observation**: 我获得了适合的表情符号。现在我已经收集了足够的信息，可以开始创作小红书爆款文案了。
#
# **Thought**: 基于收集到的信息，我将创作一篇活泼甜美、富有感染力的小红书文案。产品卖点包括：深海蓝藻提取物、透明质酸钠、24小时保湿、改善粗糙暗沉、舒缓敏感等。结合当前流行趋势"沙漠干皮救星"、"熬夜急救面膜"、"水光肌养成"，以及用户痛点"卡粉、泛红、紧绷感"。
#
# 我将创作一个吸引人的标题，正文要突出产品卖点、使用感受、适用场景，并包含真诚的推荐。标签要覆盖相关话题，表情符号要生动活泼。
#
# 现在生成最终文案：
#
# ```json
# {
#   "title": "救命！这面膜简直是沙漠干皮的救星💦敷完秒变水光肌✨",
#   "body": "姐妹们！我挖到宝了！这个深海蓝藻保湿面膜真的绝了！\n\n💙本人混干皮，一到换季就各种卡粉、泛红、紧绷感，简直要崩溃...\n\n直到遇到这款面膜，我的护肤生涯彻底被拯救了！\n\n🌊核心成分是深海蓝藻提取物，富含多种氨基酸和矿物质，还有透明质酸钠和海藻糖，保湿力MAX！\n\n✨使用感受：\n1️⃣ 天丝膜布超薄超服帖，精华液超多但完全不滴落\n2️⃣ 敷15分钟就能感觉皮肤在咕噜咕噜喝水\n3️⃣ 取下面膜后皮肤水润透亮，像剥了壳的鸡蛋\n4️⃣ 第二天上妆完全不卡粉，妆感超服帖\n\n💧最让我惊喜的是：\n- 敏感肌友好！无酒精香精，温和不刺激\n- 熬夜急救神器！第二天皮肤依然水润有光泽\n- 性价比超高！一盒10片能用一个月\n\n📌使用方法：\n洁面后敷15-20分钟，按摩吸收剩余精华，每周2-3次\n\n真心推荐给所有干皮、混干皮的姐妹！特别是经常熬夜、皮肤容易干燥的宝子们～\n\n#护肤好物分享 #一起敷面膜呀",
#   "hashtags": ["#深海蓝藻保湿面膜", "#沙漠干皮救星", "#熬夜急救面膜", "#水光肌养成", "#保湿面膜推荐"],
#   "emojis": ["💦", "✨", "💙", "🌊", "💧"]
# }
# ```
# Agent: 任务完成，成功解析最终JSON文案。
#
# --- 生成的文案 1 ---
# {
#   "title": "救命！这面膜简直是沙漠干皮的救星💦敷完秒变水光肌✨",
#   "body": "姐妹们！我挖到宝了！这个深海蓝藻保湿面膜真的绝了！\n\n💙本人混干皮，一到换季就各种卡粉、泛红、紧绷感，简直要崩溃...\n\n直到遇到这款面膜，我的护肤生涯彻底被拯救了！\n\n🌊核心成分是深海蓝藻提取物，富含多种氨基酸和矿物质，还有透明质酸钠和海藻糖，保湿力MAX！\n\n✨使用感受：\n1️⃣ 天丝膜布超薄超服帖，精华液超多但完全不滴落\n2️⃣ 敷15分钟就能感觉皮肤在咕噜咕噜喝水\n3️⃣ 取下面膜后皮肤水润透亮，像剥了壳的鸡蛋\n4️⃣ 第二天上妆完全不卡粉，妆感超服帖\n\n💧最让我惊喜的是：\n- 敏感肌友好！无酒精香精，温和不刺激\n- 熬夜急救神器！第二天皮肤依然水润有光泽\n- 性价比超高！一盒10片能用一个月\n\n📌使用方法：\n洁面后敷15-20分钟，按摩吸收剩余精华，每周2-3次\n\n真心推荐给所有干皮、混干皮的姐妹！特别是经常熬夜、皮肤容易干燥的宝子们～\n\n#护肤好物分享 #一起敷面膜呀",
#   "hashtags": [
#     "#深海蓝藻保湿面膜",
#     "#沙漠干皮救星",
#     "#熬夜急救面膜",
#     "#水光肌养成",
#     "#保湿面膜推荐"
#   ],
#   "emojis": [
#     "💦",
#     "✨",
#     "💙",
#     "🌊",
#     "💧"
#   ]
# }

# %% [markdown]
# ### 格式化 小红书文案
#
# **格式化函数 `format_rednote_for_markdown` 的功能：**
#
# 1. 解析 JSON 字符串。
# 2. 提取标题、正文、标签和表情符号。
# 3. 将它们组合成一个易读的 Markdown 格式的文本。
#
#
# **工作方式：**
#
# 1. **解析 JSON**：使用 `json.loads()` 将输入的字符串转换为 Python 字典。如果解析失败，会返回一个错误信息。
# 2. **提取数据**：使用 `.get()` 方法从字典中安全地提取 `title`、`body` 和 `hashtags`。使用 `.get()` 的好处是，如果某个键不存在，它会返回一个默认值（例如 `None` 或空列表），而不是抛出 `KeyError`。
# 3. **构建 Markdown 标题**：将 `title` 格式化为 Markdown 的二级标题 (`## Title`)。
# 4. **处理正文**：直接使用 `body`。由于小红书正文中的换行很重要，我们保留它们。
# 5. **处理 Hashtags**：将 `hashtags` 列表中的每个标签用空格连接起来，形成一行。
# 6. **表情符号 (Emojis)**：在小红书的实际发布中，表情符号通常已经嵌入在标题和正文中了。这个函数没有单独列出它们，因为这通常不是最终发布格式的一部分。如果需要，可以取消注释相关代码来单独显示它们。
# 7. **返回结果**：返回拼接好的 Markdown 字符串，并使用 `.strip()` 去除可能存在于末尾的多余空白。

# %%
import json

def format_rednote_for_markdown(json_string: str) -> str:
    """
    将 JSON 格式的小红书文案转换为 Markdown 格式，以便于阅读和发布。

    Args:
        json_string (str): 包含小红书文案的 JSON 字符串。
                           预计格式为 {"title": "...", "body": "...", "hashtags": [...], "emojis": [...]}

    Returns:
        str: 格式化后的 Markdown 文本。
    """
    try:
        data = json.loads(json_string)
    except json.JSONDecodeError as e:
        return f"错误：无法解析 JSON 字符串 - {e}\n原始字符串：\n{json_string}"

    title = data.get("title", "无标题")
    body = data.get("body", "")
    hashtags = data.get("hashtags", [])
    # 表情符号通常已经融入标题和正文中，这里可以选择是否单独列出
    # emojis = data.get("emojis", []) 

    # 构建 Markdown 文本
    markdown_output = f"## {title}\n\n" # 标题使用二级标题
    
    # 正文，保留换行符
    markdown_output += f"{body}\n\n"
    
    # Hashtags
    if hashtags:
        hashtag_string = " ".join(hashtags) # 小红书标签通常是空格分隔
        markdown_output += f"{hashtag_string}\n"
        
    # 如果需要，可以单独列出表情符号，但通常它们已经包含在标题和正文中
    # if emojis:
    #     emoji_string = " ".join(emojis)
    #     markdown_output += f"\n使用的表情：{emoji_string}\n"
        
    return markdown_output.strip() # 去除末尾多余的空白

# %%
# --- 示例使用 ---
# 假设这是 generate_rednote 函数的输出
generated_json_output = """
{
  "title": "✨ 28天逆袭冷白皮！这款美白精华让我告别暗沉痘印 🌟",
  "body": "姐妹们！我终于找到了我的本命美白精华！💖\\n\\n作为一个常年熬夜➕痘印困扰的混油皮，肤色暗沉一直是我的心头大患。直到遇见了这款美白精华，简直打开了新世界的大门！🤩\\n\\n🌟 核心成分：烟酰胺+VC衍生物，双管齐下，提亮肤色效果绝绝子！\\n💧 质地轻薄到爆炸，上脸秒吸收，完全不会黏腻，油皮姐妹放心冲！\\n🌿 用了28天，痘印肉眼可见变淡了，整张脸都透亮了起来，素颜也能打！\\n\\n使用方法也很简单：早晚洁面后，滴2-3滴在手心，轻轻按压上脸，后续再叠加保湿产品就OK啦～\\n\\n真心推荐给所有想要均匀肤色、告别暗沉的姐妹！入股不亏！💖",
  "hashtags": ["#美白精华", "#提亮肤色", "#淡化痘印", "#护肤好物", "#冷白皮"],
  "emojis": ["✨", "💖", "🤩", "💧", "🌿"]
}
"""

# 调用格式化函数
markdown_note = format_rednote_for_markdown(generated_json_output)

# 打印结果
print("--- 格式化后的小红书文案 (Markdown) ---")
print(markdown_note)

# --- 另一个例子，假设JSON解析失败 ---
invalid_json_output = "{'title': 'Test', 'body': 'This is not valid json'}" # 使用单引号，非法
markdown_error_note = format_rednote_for_markdown(invalid_json_output)
print("\n--- 格式化错误示例 ---")
print(markdown_error_note)
# Out:
# --- 格式化后的小红书文案 (Markdown) ---
# ## ✨ 28天逆袭冷白皮！这款美白精华让我告别暗沉痘印 🌟
#
# 姐妹们！我终于找到了我的本命美白精华！💖
#
# 作为一个常年熬夜➕痘印困扰的混油皮，肤色暗沉一直是我的心头大患。直到遇见了这款美白精华，简直打开了新世界的大门！🤩
#
# 🌟 核心成分：烟酰胺+VC衍生物，双管齐下，提亮肤色效果绝绝子！
# 💧 质地轻薄到爆炸，上脸秒吸收，完全不会黏腻，油皮姐妹放心冲！
# 🌿 用了28天，痘印肉眼可见变淡了，整张脸都透亮了起来，素颜也能打！
#
# 使用方法也很简单：早晚洁面后，滴2-3滴在手心，轻轻按压上脸，后续再叠加保湿产品就OK啦～
#
# 真心推荐给所有想要均匀肤色、告别暗沉的姐妹！入股不亏！💖
#
# #美白精华 #提亮肤色 #淡化痘印 #护肤好物 #冷白皮
#
# --- 格式化错误示例 ---
# 错误：无法解析 JSON 字符串 - Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# 原始字符串：
# {'title': 'Test', 'body': 'This is not valid json'}

# %% [markdown]
# 文案一：

# %%
# 调用格式化函数
markdown_note = format_rednote_for_markdown(result_1)

# 打印结果
print("--- 格式化后的小红书文案 (Markdown) ---")
print(markdown_note)
# Out:
# --- 格式化后的小红书文案 (Markdown) ---
# ## 救命！这面膜简直是沙漠干皮的救星💦敷完秒变水光肌✨
#
# 姐妹们！我挖到宝了！这个深海蓝藻保湿面膜真的绝了！
#
# 💙本人混干皮，一到换季就各种卡粉、泛红、紧绷感，简直要崩溃...
#
# 直到遇到这款面膜，我的护肤生涯彻底被拯救了！
#
# 🌊核心成分是深海蓝藻提取物，富含多种氨基酸和矿物质，还有透明质酸钠和海藻糖，保湿力MAX！
#
# ✨使用感受：
# 1️⃣ 天丝膜布超薄超服帖，精华液超多但完全不滴落
# 2️⃣ 敷15分钟就能感觉皮肤在咕噜咕噜喝水
# 3️⃣ 取下面膜后皮肤水润透亮，像剥了壳的鸡蛋
# 4️⃣ 第二天上妆完全不卡粉，妆感超服帖
#
# 💧最让我惊喜的是：
# - 敏感肌友好！无酒精香精，温和不刺激
# - 熬夜急救神器！第二天皮肤依然水润有光泽
# - 性价比超高！一盒10片能用一个月
#
# 📌使用方法：
# 洁面后敷15-20分钟，按摩吸收剩余精华，每周2-3次
#
# 真心推荐给所有干皮、混干皮的姐妹！特别是经常熬夜、皮肤容易干燥的宝子们～
#
# #护肤好物分享 #一起敷面膜呀
#
# #深海蓝藻保湿面膜 #沙漠干皮救星 #熬夜急救面膜 #水光肌养成 #保湿面膜推荐

# %% [markdown]
# ## 6. 评估与优化
#
# 文案生成并非一蹴而就，需要持续的评估和优化。本节讨论一些评估方法和优化策略。
#
# #### 评估文案质量：
# *   **客观量化评估 (数据)：**
#     *   **点赞/收藏/评论/分享：** 基础互动
#     *   **曝光/阅读/点击/涨粉：：** 流量与曝光
#     *   **停留时长/截图率：** 用户行为。
#     *   **商品页浏览/加购/ROI/成交转化：** 商业价值
#     *   **爆文率/同类横向对比：** 竞争对比
# *   **主观内部评估 (人工)：**
#     *   **相关性：** 是否符合产品特点和主题。
#     *   **吸引力：** 标题是否抓人，内容是否流畅。
#     *   **合规性：** 是否有敏感词、违规宣传。
#     *   **风格匹配：** 是否符合小红书调性和指定语气。
#     *   **用户画像：** 目标人群年龄、地域、兴趣标签。
#
#
#
# #### 优化迭代方法：
# *   **Prompt 调整：** 根据评估结果，精修 System Prompt、User Prompt，增加或修改 Few-shot 示例。
# *   **工具扩充：** 引入新的工具（如敏感词检测工具、竞品分析工具）。
# *   **RAG (检索增强生成)：** 结合更精准的内部知识库，减少幻觉。

# %% [markdown]
# ## 7. 总结与展望
#
# 通过本次实战，我们成功构建了一个基于 DeepSeek Agent 的小红书爆款文案生成助手。我们学习了如何拆解需求、设计 Prompt、定义工具，并实现 Agent 的核心工作流。
#
# Agent 在内容营销领域的潜力巨大，未来可以进一步拓展到：
#
# *   **超个性化内容：** 根据用户数据，生成一对一的定制文案。
# *   **多模态内容创作：** 结合图片、视频生成，实现图文音视频一体化。
# *   **智能营销决策：** Agent 不仅生成内容，还能分析效果并给出投放建议。
# *   **跨平台适配：** 快速生成适应不同社交媒体平台风格的文案。
#
# 同时，我们也需关注挑战，如确保内容真实性、处理高度主观情感、与现有工作流的无缝集成等。Agent 技术仍在快速发展，期待未来能带来更多惊喜！
